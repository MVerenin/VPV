# %% [markdown]
# ### Обработка данных

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as m

file3 = pd.read_csv(input(), sep = " ", names = ['l3', 'r3'])
l3 = list(file3.l3)
r3 = list(file3.r3)
lambda_wave3 = np.array(list(map(float,l3)))
R_tmp3 = np.array(list(map(float,r3)))

file1 = pd.read_csv(input(), sep = " ", names = ['l1', 'r1'])
l1 = list(file1.l1)
r1 = list(file1.r1)
lambda_wave1 = np.array(list(map(float,l1)))
R_tmp1 = np.array(list(map(float,r1))) - R_tmp3

    
file2 = pd.read_csv(input(), sep = " ", names = ['l2', 'r2'])
l2 = list(file2.l2)
r2 = list(file2.r2)
lambda_wave2 = np.array(list(map(float,l2)))
R_tmp2 = np.array(list(map(float,r2))) - R_tmp3


Y = []
for i in range(len(l1)):
    Y.append(m.log(abs((R_tmp1[i])/(R_tmp2[i]))))
w = []
for el in lambda_wave1:
    w.append(2*m.pi*3e8/(el*1e-9))
    
plt.scatter(w, Y, s = 1, color = "Blue")
plt.title('P = 7.8 Вт')
plt.xlabel('Длина волны, нм')
plt.grid(which='major')
plt.show()

#C:\Users\Максим.DESKTOP-N5OPJQH\Desktop\ВПВ\основные_данные\bg 10ms.txt
#C:\Users\Максим.DESKTOP-N5OPJQH\Desktop\ВПВ\основные_данные\dt 1.5 1.5 2.6 2.6 10ms.txt
#C:\Users\Максим.DESKTOP-N5OPJQH\Desktop\ВПВ\основные_данные\dt 1.6 1.5 2.7 2.7 10ms.txt
# Out:
# C:\Users\Максим.DESKTOP-N5OPJQH\Desktop\ВПВ\основные_данные\bg 10ms.txt
# C:\Users\Максим.DESKTOP-N5OPJQH\Desktop\ВПВ\основные_данные\dt 1.5 1.5 2.6 2.6 10ms.txt
# C:\Users\Максим.DESKTOP-N5OPJQH\Desktop\ВПВ\основные_данные\dt 1.6 1.5 2.7 2.7 10ms.txt

# %%
import pandas as pd
import matplotlib.pyplot as plt
file1 = pd.read_csv(input(), sep = " ", names = ['l', 'r'])
l = list(file1.l)
r = list(file1.r)
lambda_wave = list(map(float,l))
R = list(map(float,r))
plt.scatter(lambda_wave, R)
plt.show()
# Out:
# C:\Users\Максим.DESKTOP-N5OPJQH\Desktop\ВПВ\основные_данные\bg 10ms.txt

# %%
import pandas as pd
import matplotlib.pyplot as plt
file1 = pd.read_csv(input(), sep = " ", names = ['l', 'r'])
l = list(file1.l)
r = list(file1.r)
lambda_wave = list(map(float,l))
R = list(map(float,r))
plt.scatter(lambda_wave, R)
plt.show()
# Out:
# C:\Users\Максим.DESKTOP-N5OPJQH\Downloads\Telegram_Desktop\Данные_ВПВ\Данные_ВПВ\основные_данные\dt 1.7 1.5 2.8 2.8 10ms.txt

# %%
import pandas as pd
import matplotlib.pyplot as plt
file1 = pd.read_csv(input(), sep = " ", names = ['l', 'r'])
l = list(file1.l)
r = list(file1.r)
lambda_wave = list(map(float,l))
R = list(map(float,r))
plt.scatter(lambda_wave, R)
plt.show()
# Out:
# C:\Users\Максим.DESKTOP-N5OPJQH\Downloads\Telegram_Desktop\Данные_ВПВ\Данные_ВПВ\основные_данные\dt 1.8 1.5 3.1 3.1 10ms.txt

# %%
import pandas as pd
import matplotlib.pyplot as plt
file1 = pd.read_csv(input(), sep = " ", names = ['l', 'r'])
l = list(file1.l)
r = list(file1.r)
lambda_wave = list(map(float,l))
R = list(map(float,r))
plt.scatter(lambda_wave, R)
plt.show()
# Out:
# C:\Users\Максим.DESKTOP-N5OPJQH\Downloads\Telegram_Desktop\Данные_ВПВ\Данные_ВПВ\основные_данные\dt 1.9 1.5 3.2 3.2 10ms.txt

# %%
import pandas as pd
import matplotlib.pyplot as plt
file1 = pd.read_csv(input(), sep = " ", names = ['l', 'r'])
l = list(file1.l)
r = list(file1.r)
lambda_wave = list(map(float,l))
R = list(map(float,r))
plt.scatter(lambda_wave, R)
plt.show()
# Out:
# C:\Users\Максим.DESKTOP-N5OPJQH\Downloads\Telegram_Desktop\Данные_ВПВ\Данные_ВПВ\основные_данные\dt 2.0 1.5 3.4 3.4 10ms.txt

# %%
import pandas as pd
import matplotlib.pyplot as plt
file1 = pd.read_csv(input(), sep = " ", names = ['l', 'r'])
l = list(file1.l)
r = list(file1.r)
lambda_wave = list(map(float,l))
R = list(map(float,r))
plt.scatter(lambda_wave, R)
plt.show()
# Out:
# C:\Users\Максим.DESKTOP-N5OPJQH\Downloads\Telegram_Desktop\Данные_ВПВ\Данные_ВПВ\основные_данные\dt 2.1 1.5 3.5 3.5 10ms.txt

# %%
import pandas as pd
import matplotlib.pyplot as plt
file1 = pd.read_csv(input(), sep = " ", names = ['l', 'r'])
l = list(file1.l)
r = list(file1.r)
lambda_wave = list(map(float,l))
R = list(map(float,r))
plt.scatter(lambda_wave, R)
plt.show()
# Out:
# C:\Users\Максим.DESKTOP-N5OPJQH\Downloads\Telegram_Desktop\Данные_ВПВ\Данные_ВПВ\основные_данные\dt 2.2 1.5 3.7 3.7 10ms.txt

# %%
import pandas as pd
import matplotlib.pyplot as plt
file1 = pd.read_csv(input(), sep = " ", names = ['l', 'r'])
l = list(file1.l)
r = list(file1.r)
lambda_wave = list(map(float,l))
R = list(map(float,r))
plt.scatter(lambda_wave, R)
plt.show()
# Out:
# C:\Users\Максим.DESKTOP-N5OPJQH\Downloads\Telegram_Desktop\Данные_ВПВ\Данные_ВПВ\основные_данные\dt 2.3 1.5 3.9 3.9 10ms.txt

# %%
import pandas as pd
import matplotlib.pyplot as plt
file1 = pd.read_csv(input(), sep = " ", names = ['l', 'r'])
l = list(file1.l)
r = list(file1.r)
lambda_wave = list(map(float,l))
R = list(map(float,r))
plt.scatter(lambda_wave, R)
plt.show()
# Out:
# C:\Users\Максим.DESKTOP-N5OPJQH\Downloads\Telegram_Desktop\Данные_ВПВ\Данные_ВПВ\основные_данные\dt 2.4 1.5 4.1 4.0 10ms.txt

# %%
import pandas as pd
import matplotlib.pyplot as plt
file1 = pd.read_csv(input(), sep = " ", names = ['l', 'r'])
l = list(file1.l)
r = list(file1.r)
lambda_wave = list(map(float,l))
R = list(map(float,r))
plt.scatter(lambda_wave, R)
plt.show()
# Out:
# C:\Users\Максим.DESKTOP-N5OPJQH\Downloads\Telegram_Desktop\Данные_ВПВ\Данные_ВПВ\основные_данные\dt 2.5 1.5 4.2 4.2 10ms.txt

# %%
import pandas as pd
import matplotlib.pyplot as plt
file1 = pd.read_csv(input(), sep = " ", names = ['l', 'r'])
l = list(file1.l)
r = list(file1.r)
lambda_wave = list(map(float,l))
R = list(map(float,r))
plt.scatter(lambda_wave, R)
plt.show()
# Out:
# C:\Users\Максим.DESKTOP-N5OPJQH\Downloads\Telegram_Desktop\Данные_ВПВ\Данные_ВПВ\основные_данные\dt 2.6 1.5 4.4 4.3 10ms.txt

# %%
import pandas as pd
import matplotlib.pyplot as plt
file1 = pd.read_csv(input(), sep = " ", names = ['l', 'r'])
l = list(file1.l)
r = list(file1.r)
lambda_wave = list(map(float,l))
R = list(map(float,r))
plt.scatter(lambda_wave, R)
plt.show()
# Out:
# C:\Users\Максим.DESKTOP-N5OPJQH\Downloads\Telegram_Desktop\Данные_ВПВ\Данные_ВПВ\основные_данные\dt 2.6 1.6 4.5 4.5 10ms.txt

# %%
import pandas as pd
import matplotlib.pyplot as plt
file1 = pd.read_csv(input(), sep = " ", names = ['l', 'r'])
l = list(file1.l)
r = list(file1.r)
lambda_wave = list(map(float,l))
R = list(map(float,r))
plt.scatter(lambda_wave, R)
plt.show()
# Out:
# C:\Users\Максим.DESKTOP-N5OPJQH\Downloads\Telegram_Desktop\Данные_ВПВ\Данные_ВПВ\основные_данные\dt 2.6 1.7 4.6 4.6 5ms.txt

# %%
import pandas as pd
import matplotlib.pyplot as plt
file1 = pd.read_csv(input(), sep = " ", names = ['l', 'r'])
l = list(file1.l)
r = list(file1.r)
lambda_wave = list(map(float,l))
R = list(map(float,r))
plt.scatter(lambda_wave, R)
plt.show()
# Out:
# C:\Users\Максим.DESKTOP-N5OPJQH\Downloads\Telegram_Desktop\Данные_ВПВ\Данные_ВПВ\основные_данные\dt 2.6 1.8 4.8 4.8 5ms.txt

# %%
import pandas as pd
import matplotlib.pyplot as plt
file1 = pd.read_csv(input(), sep = " ", names = ['l', 'r'])
l = list(file1.l)
r = list(file1.r)
lambda_wave = list(map(float,l))
R = list(map(float,r))
plt.scatter(lambda_wave, R)
plt.show()
# Out:
# C:\Users\Максим.DESKTOP-N5OPJQH\Downloads\Telegram_Desktop\Данные_ВПВ\Данные_ВПВ\основные_данные\dt 2.6 1.9 5.0 5.0 5ms.txt

# %%
import pandas as pd
import matplotlib.pyplot as plt
file1 = pd.read_csv(input(), sep = " ", names = ['l', 'r'])
l = list(file1.l)
r = list(file1.r)
lambda_wave = list(map(float,l))
R = list(map(float,r))
plt.scatter(lambda_wave, R)
plt.show()
# Out:
# C:\Users\Максим.DESKTOP-N5OPJQH\Downloads\Telegram_Desktop\Данные_ВПВ\Данные_ВПВ\основные_данные\dt 2.6 2.0 5.2 5.2 5ms.txt

# %%
import pandas as pd
import matplotlib.pyplot as plt
file1 = pd.read_csv(input(), sep = " ", names = ['l', 'r'])
l = list(file1.l)
r = list(file1.r)
lambda_wave = list(map(float,l))
R = list(map(float,r))
plt.scatter(lambda_wave, R)
plt.show()
# Out:
# C:\Users\Максим.DESKTOP-N5OPJQH\Downloads\Telegram_Desktop\Данные_ВПВ\Данные_ВПВ\основные_данные\dt 2.6 2.1 5.4 5.4 5ms.txt

# %%
import pandas as pd
import matplotlib.pyplot as plt
file1 = pd.read_csv(input(), sep = " ", names = ['l', 'r'])
l = list(file1.l)
r = list(file1.r)
lambda_wave = list(map(float,l))
R = list(map(float,r))
plt.scatter(lambda_wave, R)
plt.show()
# Out:
# C:\Users\Максим.DESKTOP-N5OPJQH\Downloads\Telegram_Desktop\Данные_ВПВ\Данные_ВПВ\основные_данные\dt 2.6 2.2 5.6 5.6 5ms.txt

# %%
print(3e8)
# Out:
# 300000000.0

# %%
a=np.array([1,2,3,4,5,6])
b=np.array([2,3,4,5,6,7])
print(b-a)
# Out:
# [1 1 1 1 1 1]
